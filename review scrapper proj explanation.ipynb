# %% [markdown]
# # Our tasks here are:
# ## 1) go to a website
# ## 2) search for a respective product
# ## 3) locate the review part
# ## 4) scrap all the data in my local system.

# %% [markdown]
# In a layman way, we go to flipkart website, search iphone, click on product and in the bottom it shows reviews.
# now we have to do this all using python code.

# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# ...
#   Using cached bs4-0.0.1-py3-none-any.whl
# ...
#   Using cached certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# ...
#   Using cached Flask_Cors-3.0.9-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# ...
#   Using cached MarkupSafe-1.1.1-cp39-cp39-win_amd64.whl (16 kB)Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# ...

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %% [raw]
# e.g. "https://www.flipkart.com/search?q=" + "iphone7" =
#
# "https://www.flipkart.com/search?q=iphone7"

# %% [raw]
# e.g. "https://www.flipkart.com/search?q=" + "samsung" =
#
# "https://www.flipkart.com/search?q=samsung"
#
# This url showcases all samsung products.

# %% [raw]
# so now 1st 2 tasks go to web and search for product are done in this url "https://www.flipkart.com/search?q=samsung"

# %% [raw]
# flipkart_url = "https://www.flipkart.com/search?q=" + searchString

# %%
flipkart_url1 = "https://www.flipkart.com/search?q=samsung"

# %%
uClient = uReq(flipkart_url1)

# url open from urllib.request imported as uReq above and it is used to simply open a url.
uClient

#If we pass wrong url, it gives error.

# %%
flipkartPage = uClient.read()
flipkartPage #read text

# But not returned in a very readable format, when we rightclick on any page and click on view page source, it prints
# the same below format of any webpage.
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")# bs is beautiful soap library which beautifies the unreadable text.
flipkart_html
#This output and above both are almost same but the below one is just structured line by line.
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# now to filter out only those boxes which are search results of iphone or any such product, click fn+F12 which shows html tags of any webpage, then click on top right mouse cursor of that page which changes mouse cursor so as wherever we click on main
# screen, it's corresponding tag containing it's division class appears, their may be subclasses also inside one main  div class, but by scrolling mouse on different boxes of product search results, 1st scroll mouse in such a way that it is able to select the whole product result box, we get different tags containing same division class e.g. in below case for iphone search results which represents each product result box and in below iphone e.g. name of that division class is _1AtVbE col-12-12.
#
# searching that division class out of whole flipkart_html prints all iphone based results and len of that = 15 means there
# have been 15 iphone search results.

# %% [raw]
# Similarly on flipkart website e.g., class _2I9KP_ represents those buttons at the top of webpage which are for Electronics, Furniture, Home products etc.

# %%
bigBoxes = flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})
bigBoxes
# We are searching for division class named "_1AtVbE col-12-12"
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall
# ...

# %%
len(bigBoxes)
#This means 15 iphones listed out in search.
# Out:
# 14

# %%
for i in bigBoxes:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall 
# ...

# %%
bigBoxes[0]#represents very 1st iphone search result.
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall 
# ...

# %% [markdown]
# # Now we need to find out the url of that box i.e. href

# %%
box = bigBoxes[0]
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="_2SqgSY" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="_2SqgSY" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall 
# ...

# %% [markdown]
# as we studied above that a div class may have sub classes shown on clicking on downwards arrow, and we keep on opening subclasses of each sub class further and further and after opening 3 steps sublacces, we find that href url given.

# %%
box.div.div.div.a #So we try moving 3 steps below, but as of now didn't fetch anything

# %%
del bigBoxes[0:3] 
#bigBoxes denote the search result boxes, but 1st 3 search box results were not having href in their tag classes.

# we noticed on different html tags of div classes named, 1st 3 were were not having href url,
#so we delete them so that href for all below can be extracted

# %% [raw]
# Maybe in future usecases, this del bigBoxes[0:3] could be handled by try-except instead of manual handling.

# %%
box = bigBoxes[0]

# %%
box.div#Below going forward step by step.
# Out:
# <div class="_13oc-S"><div data-id="ACCGYGTHRZZXBHZF" style="width:25%"><div class="_4ddWXP"><a class="_2rpwqI" href="/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&amp;lid=LSTACCGYGTHRZZXBHZFW7LDKU&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_9&amp;otracker=search&amp;fm=organic&amp;iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dpe72etpfk0000001668836499760&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div><div><div class="CXW8mj" style="height:280px;width:200px"><img alt="SAMSUNG Original 25W ,USB -C Compatible Power Adaptor for all Samsung Devices (Fast Charge 2.0)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/612/612/kl2mljk0/battery-charger/x/0/u/ep-ta800-samsung-original-imagya36jzxk5sgm.jpeg?q=70"/></div></div></div><div class="_2hVSre _1eAP-x"><div class="_36FSn5"><svg cla
# ...

# %%
box.div.div
# Out:
# <div data-id="ACCGYGTHRZZXBHZF" style="width:25%"><div class="_4ddWXP"><a class="_2rpwqI" href="/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&amp;lid=LSTACCGYGTHRZZXBHZFW7LDKU&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_9&amp;otracker=search&amp;fm=organic&amp;iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dpe72etpfk0000001668836499760&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div><div><div class="CXW8mj" style="height:280px;width:200px"><img alt="SAMSUNG Original 25W ,USB -C Compatible Power Adaptor for all Samsung Devices (Fast Charge 2.0)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/612/612/kl2mljk0/battery-charger/x/0/u/ep-ta800-samsung-original-imagya36jzxk5sgm.jpeg?q=70"/></div></div></div><div class="_2hVSre _1eAP-x"><div class="_36FSn5"><svg class="_1l0elc" height="
# ...

# %%
box.div.div.div#This step has href url
# Out:
# <div class="_4ddWXP"><a class="_2rpwqI" href="/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&amp;lid=LSTACCGYGTHRZZXBHZFW7LDKU&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_9&amp;otracker=search&amp;fm=organic&amp;iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dpe72etpfk0000001668836499760&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div><div><div class="CXW8mj" style="height:280px;width:200px"><img alt="SAMSUNG Original 25W ,USB -C Compatible Power Adaptor for all Samsung Devices (Fast Charge 2.0)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/612/612/kl2mljk0/battery-charger/x/0/u/ep-ta800-samsung-original-imagya36jzxk5sgm.jpeg?q=70"/></div></div></div><div class="_2hVSre _1eAP-x"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://w
# ...

# %%
box.div.div.div.a['href']#here we get url of that product
# Out:
# '/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&lid=LSTACCGYGTHRZZXBHZFW7LDKU&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_9&otracker=search&fm=organic&iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&ppt=None&ppn=None&ssid=dpe72etpfk0000001668836499760&qH=fe546279a62683de'

# %%
#append with base flipkart url
"https://www.flipkart.com/search?q=samsung" + box.div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/search?q=samsung/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&lid=LSTACCGYGTHRZZXBHZFW7LDKU&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_9&otracker=search&fm=organic&iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&ppt=None&ppn=None&ssid=dpe72etpfk0000001668836499760&qH=fe546279a62683de'

# %%
productLink = "https://www.flipkart.com/search?q=samsung" + box.div.div.div.a['href']
productLink

#search this url in browser and u'll reach the iphone product page
# Out:
# 'https://www.flipkart.com/search?q=samsung/samsung-original-25w-usb-c-compatible-power-adaptor-all-devices-fast-charge-2-0/p/itm2f38a030cccb8?pid=ACCGYGTHRZZXBHZF&lid=LSTACCGYGTHRZZXBHZFW7LDKU&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_9&otracker=search&fm=organic&iid=4f2de94f-3133-40f9-bba9-339e8a81d5b2.ACCGYGTHRZZXBHZF.SEARCH&ppt=None&ppn=None&ssid=dpe72etpfk0000001668836499760&qH=fe546279a62683de'

# %% [markdown]
# Now out of this url page, we need to go to reviews section

# %%
prodRes = requests.get(productLink)
prodRes
# Out:
# <Response [200]>

# %%
prodRes.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57"
# ...

# %%
prodRes.encoding='utf-8' #encode it in english format utf-8 and nothing else.
prod_html = bs(prodRes.text, "html.parser")#beautifulsoup for better presentable as done above
print(prod_html)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# Now when we go through the above url which opens product, we again have to search for div class for boxes of all reviews of that product as we did above and class turns out to be "_16PBlm".

# %% [markdown]
# ### commentboxes contains all boxes having ratings, commentheads, names and comments i.e. those boxes at the bottom of each product.

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER <br/>The difference is not too much, but yes 25 w is a bit faster than 15 w charger .<br/>As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.<br/>It's 100 percent now at 10.34 <br/>It took the phone 42 Minute...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202207/blobio-imr-202207_9
# ...

# %%
len(commentboxes)#11 reviews given on that page.
# Out:
# 11

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER <br/>The difference is not too much, but yes 25 w is a bit faster than 15 w charger .<br/>As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.<br/>It's 100 percent now at 10.34 <br/>It took the phone 42 Minute...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202207/blobio-imr-202207_9b78b008792b49998e5fc4d111edb381.jpg?q=9
# ...

# %%
commentboxes[0].div.div.div #Some data skipped so we will stick to commentboxes[0].div.div
#bcoz see output below, we can't find anything meaningful
# Out:
# <div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div>

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})
#'class': '_2sc7ZR _2V5EHH' represents name of person who has written review and this is p class and not div class.
#class extracted same way as done in above cases
# Out:
# [<p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>]

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0]#extract out of list
# Out:
# <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text#This is how name of person extracted.
# Out:
# 'Flipkart Customer'

# %%
for i in range(len(commentboxes)-1):# len(commentBoxes)=11 as explained above
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    
#Names of all those customers who had written review printed.
# Out:
# Flipkart Customer
# ABHISHEK M D
# Praveen Pandian
# RAJESH YADAV
# Suyog Ghinmine
# Sukhdev Jadhav
# Kumar Pujala
# Y. Bala sundeep
# Manjunath Tengli
# IndraNil Pachore

# %% [markdown]
# Now to extract ratings, again surf through subclasses

# %%
commentboxes[0].div.div #in below output, 3 in 1st line is the rating
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER <br/>The difference is not too much, but yes 25 w is a bit faster than 15 w charger .<br/>As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.<br/>It's 100 percent now at 10.34 <br/>It took the phone 42 Minute...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202207/blobio-imr-202207_9b78b008792b49998e5fc4d111edb381.jpg?q=9
# ...

# %%
commentboxes[0].div.div.div
# Out:
# <div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div>

# %%
commentboxes[0].div.div.div.div# 3 rating can be extracted at this level also.
# Out:
# <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>

# %%
commentboxes[0].div.div.div.div.text#rating printed
# Out:
# '4'

# %%
for i in range(len(commentboxes)-1):# len(commentBoxes)=11 as explained above
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    
#Aloka Sahu rated product as 3 and so on........
# Out:
# Flipkart Customer
# 4
# ABHISHEK M D
# 4
# Praveen Pandian
# 5
# RAJESH YADAV
# 5
# Suyog Ghinmine
# 5
# Sukhdev Jadhav
# 4
# Kumar Pujala
# 5
# Y. Bala sundeep
# 2
# Manjunath Tengli
# 5
# IndraNil Pachore
# 4

# %% [markdown]
# Now we have to extract comments

# %%
commentboxes[0].div.div.div
#Just note at the right of 3rd line, it is p class inside which Fair comment in last line given
# Out:
# <div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div>

# %%
commentboxes[0].div.div.div.p
# Out:
# <p class="_2-N8zT">Really Nice</p>

# %%
commentboxes[0].div.div.div.p.text
# Out:
# 'Really Nice'

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Really Nice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER <br/>The difference is not too much, but yes 25 w is a bit faster than 15 w charger .<br/>As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.<br/>It's 100 percent now at 10.34 <br/>It took the phone 42 Minute...</div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202207/blobio-imr-202207_9b78b008792b49998e5fc4d111edb381.jpg?q=9
# ...

# %%
commentboxes[0].div.div.find_all('div',{'class':''})#Class specified as '' bcoz check class in html tags like above,
                                                    # it is just given <div class> and not anyting else.
# Out:
# [<div><div class="">I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER <br/>The difference is not too much, but yes 25 w is a bit faster than 15 w charger .<br/>As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.<br/>It's 100 percent now at 10.34 <br/>It took the phone 42 Minute...</div><span class="_1BWGvX"><span>READ MORE</span></span></div>,
# ...

# %%
commentboxes[0].div.div.find_all('div',{'class':''})[0].text
# Out:
# "I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER The difference is not too much, but yes 25 w is a bit faster than 15 w charger .As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.It's 100 percent now at 10.34 It took the phone 42 Minute...READ MORE"

# %%
for i in range(len(commentboxes)-1):# len(commentBoxes)=11 as explained above
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].div.div.find_all('div',{'class':''})[0].text)
# Out:
# Flipkart Customer
# 4
# I am updating the review. The charging problem earlier was in my phone which I got fixed, now I can see improvement in the speed with this charger compared to the 15W CHARGER The difference is not too much, but yes 25 w is a bit faster than 15 w charger .As you can see in the 2nd picture, with 72 percent already, super charger shows 48 mins more at 9.52 PM But I think it should be done with 15 minutes. Let's check. Will update here.It's 100 percent now at 10.34 It took the phone 42 Minute...READ MORE
# ABHISHEK M D
# 4
# One more Good Experince from Flipkart .. Best deal ... Initially felt like first copy .. but after checking the part no. seems like Genuine Samsung product .. no Heating issues what so ever ..READ MORE
# Praveen Pandian
# 5
# Works perfectly fine! Charging time has reduced by almost an hour for my A52, very satisfied and would definitely recommend it.READ MORE
# RAJESH YADAV
# 5
# good fast charger work wery well with my s21+READ MORE
# ...

# %% [raw]
# Amazon has limit of accessing ip address for scrapping 20 times and more than that they will block u and u'll have to use vpn.
# varies website to website.

# %%
"iphone ".replace(" ","")
# Out:
# 'iphone'
